# %% [markdown]
# # Physicochemical diversity of compounds found in patents
# This notebook calculates the distribution between the physicochemical properties of the SureChEMBL compounds per year.

# %% [markdown]
# # Import Modules

# %%
import pandas as pd
from tqdm import tqdm

tqdm.pandas()

# %% [markdown]
# # Add path constants

# %%
PROCESSED_DIR = "../data/processed"
MAPPING_DIR = "../data/mappings"

# %% [markdown]
# # Load data file

# %%
property_df = pd.read_csv(
    f"{MAPPING_DIR}/property_data.tsv", sep="\t", low_memory=False
)

year_df = pd.read_parquet(f"{PROCESSED_DIR}/patent_data_desalted.pq")

# %%
property_combined_df = pd.merge(
    property_df, year_df, how="left", left_on="SMILES", right_on="cleaned_smiles"
)
property_combined_df.drop(columns=["cleaned_smiles", "n_chiral"], inplace=True)
property_combined_df.rename(
    columns={"SMILES_x": "desalted_SMILES", "SMILES_y": "SMILES"}, inplace=True
)
property_combined_df.head(2)
# Out:
#                                      desalted_SMILES          mw    logp  \
# 0  C1=C2C(c3ccc(-c4cccc5ccccc45)cc3)=NC(n3c4ccccc...  604.226312  9.5483
# 1  C=CCOC(=O)[C@@H]1C[C@]2(C(C)Cc3ccc(OC)c(C=O)c3...  400.152203  2.6315
#
#    n_hba  n_hbd   tpsa  rot_bonds      fsp3  n_ring  n_heteroatoms  \
# 0      5      0  43.81          3  0.047619      10              5
# 1      7      0  88.13          8  0.409091       3              7
#
#                                               SMILES  year
# 0  C1OC=C2C1N=C(N=C2C1=CC=C(C=C1)C1=CC=CC2=C1C=CC...  2015
# 1  COC1=C(C=O)C=C(CC(C)[C@]23C[C@@H](C(=O)OCC=C)C...  2017

# %% [markdown]
# # Statistical distribution of molecular properties each year

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
t_median = []

for year in tqdm(property_combined_df["year"].unique()):
    k = property_combined_df[property_combined_df["year"] == year].drop(
        columns=["desalted_SMILES", "SMILES", "year"]
    )
    m = k.median(axis=0).to_dict()
    m["year"] = year
    t_median.append(m)

df_median = pd.DataFrame(t_median)
df_median.sort_values(by=["year"], inplace=True)
df_median
# Out:
# 100%|██████████| 8/8 [00:05<00:00,  1.59it/s]
#       mw  logp  n_hba  n_hbd  tpsa  rot_bonds  fsp3  n_ring  n_heteroatoms  \
# 0 394.03  3.52   5.00   1.00 72.94       5.00  0.36    3.00           7.00
# 5 416.09  3.73   5.00   1.00 75.27       5.00  0.36    4.00           7.00
# 1 420.15  3.77   5.00   1.00 71.93       5.00  0.38    4.00           7.00
# 7 421.27  3.85   5.00   1.00 72.47       5.00  0.36    4.00           7.00
# 3 427.17  3.78   5.00   1.00 74.68       5.00  0.38    4.00           7.00
# 6 436.26  3.85   5.00   1.00 74.76       5.00  0.37    4.00           7.00
# 4 440.11  3.87   5.00   1.00 74.69       5.00  0.38    4.00           7.00
# 2 461.24  4.13   5.00   1.00 72.19       5.00  0.38    4.00           7.00
#
#    year
# 0  2015
# 5  2016
# 1  2017
# 7  2018
# 3  2019
# 6  2020
# 4  2021
# 2  2022

# %%
t_mean = []

for year in tqdm(property_combined_df["year"].unique()):
    k = property_combined_df[property_combined_df["year"] == year].drop(
        columns=["desalted_SMILES", "SMILES", "year"]
    )
    m = k.mean(axis=0).to_dict()
    m["year"] = year
    t_mean.append(m)

df_mean = pd.DataFrame(t_mean)
df_mean.sort_values(by=["year"], inplace=True)
df_mean
# Out:
# 100%|██████████| 8/8 [00:03<00:00,  2.47it/s]
#       mw  logp  n_hba  n_hbd  tpsa  rot_bonds  fsp3  n_ring  n_heteroatoms  \
# 0 407.84  3.92   5.07   1.49 78.90       5.92  0.39    3.46           7.26
# 5 437.60  4.29   5.36   1.55 82.64       6.31  0.38    3.84           7.66
# 1 450.68  4.56   5.33   1.62 81.40       6.52  0.41    4.01           7.49
# 7 451.07  4.61   5.35   1.53 80.43       6.52  0.39    4.02           7.56
# 3 460.80  4.67   5.49   1.57 82.21       6.48  0.40    4.21           7.71
# 6 471.94  4.90   5.56   1.55 82.94       6.52  0.39    4.42           7.80
# 4 474.90  4.90   5.58   1.57 82.77       6.51  0.39    4.47           7.78
# 2 498.41  5.43   5.70   1.50 81.79       6.71  0.39    4.94           7.83
#
#    year
# 0  2015
# 5  2016
# 1  2017
# 7  2018
# 3  2019
# 6  2020
# 4  2021
# 2  2022
